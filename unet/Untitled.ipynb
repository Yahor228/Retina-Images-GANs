# %%
from model import *
from data import *

#os.environ["CUDA_VISIBLE_DEVICES"] = "0"


data_gen_args = dict(rotation_range=0.2,
                    width_shift_range=0.05,
                    height_shift_range=0.05,
                    shear_range=0.05,
                    zoom_range=0.05,
                    horizontal_flip=True,
                    fill_mode='nearest')
#myGene = trainGenerator(2,'data/membrane/train','image','label',data_gen_args,save_to_dir = None)

#model = unet()
# model_checkpoint = ModelCheckpoint('unet_membrane.hdf5', monitor='loss',verbose=1, save_best_only=True)
# model.fit_generator(myGene,steps_per_epoch=300,epochs=1,callbacks=[model_checkpoint])



model = tf.keras.models.load_model("unet_membrane.hdf5")

testGene = testGenerator("data/membrane/test")
results = model.predict(testGene, steps=34, verbose=1)
saveResult("data/membrane/test",results)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from model import *
#       2 from data import *
#       4 #os.environ["CUDA_VISIBLE_DEVICES"] = "0"
#
# File ~/Desktop/BP/unet/model.py:3
#       1 import numpy as np
#       2 import os
# ----> 3 import skimage.io as io
#       4 import skimage.transform as trans
#       5 import numpy as np
#
# File ~/.local/lib/python3.10/site-packages/skimage/__init__.py:128
#     125     _raise_build_error(e)
#     127 # Legacy imports into the root namespace; not advertised in __all__
# --> 128 from .util.dtype import (
#     129     dtype_limits,
#     130     img_as_float32,
#     131     img_as_float64,
#     132     img_as_float,
#     133     img_as_int,
#     134     img_as_uint,
#     135     img_as_ubyte,
#     136     img_as_bool
#     137 )
#     139 from .util.lookfor import lookfor
#     141 from .data import data_dir
#
# File ~/.local/lib/python3.10/site-packages/skimage/util/__init__.py:16
#      14 from .unique import unique_rows
#      15 from ._invert import invert
# ---> 16 from ._montage import montage
#      17 from ._map_array import map_array
#      18 from ._label import label_points
#
# File ~/.local/lib/python3.10/site-packages/skimage/util/_montage.py:4
#       1 import numpy as np
#       3 from .._shared import utils
# ----> 4 from .. import exposure
#       6 __all__ = ['montage']
#       9 @utils.channel_as_last_axis(multichannel_output=False)
#      10 def montage(arr_in, fill='mean', rescale_intensity=False, grid_shape=None,
#      11             padding_width=0, *, channel_axis=None):
#
# File ~/.local/lib/python3.10/site-packages/skimage/exposure/__init__.py:6
#       1 from .exposure import histogram, equalize_hist, \
#       2                       rescale_intensity, cumulative_distribution, \
#       3                       adjust_gamma, adjust_sigmoid, adjust_log, \
#       4                       is_low_contrast
# ----> 6 from ._adapthist import equalize_adapthist
#       7 from .histogram_matching import match_histograms
#      10 __all__ = ['histogram',
#      11            'equalize_hist',
#      12            'equalize_adapthist',
#    (...)
#      18            'is_low_contrast',
#      19            'match_histograms']
#
# File ~/.local/lib/python3.10/site-packages/skimage/exposure/_adapthist.py:13
#      10 import numpy as np
#      12 from .._shared.utils import _supported_float_type
# ---> 13 from ..color.adapt_rgb import adapt_rgb, hsv_value
#      14 from ..exposure import rescale_intensity
#      15 from ..util import img_as_uint
#
# File ~/.local/lib/python3.10/site-packages/skimage/color/__init__.py:1
# ----> 1 from .colorconv import (convert_colorspace,
#       2                         rgba2rgb,
#       3                         rgb2hsv,
#       4                         hsv2rgb,
#       5                         rgb2xyz,
#       6                         xyz2rgb,
#       7                         rgb2rgbcie,
#       8                         rgbcie2rgb,
#       9                         rgb2gray,
#      10                         gray2rgb,
#      11                         gray2rgba,
#      12                         xyz2lab,
#      13                         lab2xyz,
#      14                         lab2rgb,
#      15                         rgb2lab,
#      16                         xyz2luv,
#      17                         luv2xyz,
#      18                         luv2rgb,
#      19                         rgb2luv,
#      20                         rgb2hed,
#      21                         hed2rgb,
#      22                         lab2lch,
#      23                         lch2lab,
#      24                         rgb2yuv,
#      25                         yuv2rgb,
#      26                         rgb2yiq,
#      27                         yiq2rgb,
#      28                         rgb2ypbpr,
#      29                         ypbpr2rgb,
#      30                         rgb2ycbcr,
#      31                         ycbcr2rgb,
#      32                         rgb2ydbdr,
#      33                         ydbdr2rgb,
#      34                         separate_stains,
#      35                         combine_stains,
#      36                         rgb_from_hed,
#      37                         hed_from_rgb,
#      38                         rgb_from_hdx,
#      39                         hdx_from_rgb,
#      40                         rgb_from_fgx,
#      41                         fgx_from_rgb,
#      42                         rgb_from_bex,
#      43                         bex_from_rgb,
#      44                         rgb_from_rbd,
#      45                         rbd_from_rgb,
#      46                         rgb_from_gdx,
#      47                         gdx_from_rgb,
#      48                         rgb_from_hax,
#      49                         hax_from_rgb,
#      50                         rgb_from_bro,
#      51                         bro_from_rgb,
#      52                         rgb_from_bpx,
#      53                         bpx_from_rgb,
#      54                         rgb_from_ahx,
#      55                         ahx_from_rgb,
#      56                         rgb_from_hpx,
#      57                         hpx_from_rgb)
#      59 from .colorlabel import color_dict, label2rgb
#      61 from .delta_e import (deltaE_cie76,
#      62                       deltaE_ciede94,
#      63                       deltaE_ciede2000,
#      64                       deltaE_cmc,
#      65                       )
#
# File ~/.local/lib/python3.10/site-packages/skimage/color/colorconv.py:396
#     387 # ---------------------------------------------------------------
#     388 # Matrices that define conversion between different color spaces
#     389 # ---------------------------------------------------------------
#     390
#     391 # From sRGB specification
#     392 xyz_from_rgb = np.array([[0.412453, 0.357580, 0.180423],
#     393                          [0.212671, 0.715160, 0.072169],
#     394                          [0.019334, 0.119193, 0.950227]])
# --> 396 rgb_from_xyz = linalg.inv(xyz_from_rgb)
#     398 # From https://en.wikipedia.org/wiki/CIE_1931_color_space
#     399 # Note: Travis's code did not have the divide by 0.17697
#     400 xyz_from_rgbcie = np.array([[0.49, 0.31, 0.20],
#     401                             [0.17697, 0.81240, 0.01063],
#     402                             [0.00, 0.01, 0.99]]) / 0.17697
#
# AttributeError: module 'scipy.linalg' has no attribute 'inv'
